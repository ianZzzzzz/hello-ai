# %%
#本次任务代码由助教提供
#目的为测试不同优化器对结果的影响
import keras        
from keras import models
from keras import layers
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import random
import shutil 
import math
import cv2
import os

# %% [markdown]
# -----------請輸入你的train、val資料位置、類別總數、訓練次數(num_epoch)、測試圖片-----------

# %%
train_path = r'C:\AI\data_2\train'
val_path = r'C:\AI\data_2\val'
test_image_path = r'C:\AI\data_2\val\nike\1.jpg' # 測試圖片
num_classes = 2 # change to your number of class    
num_epoch = 60

# %% [markdown]
# ------------------------------------cell1 end-----------------------------------------

# %%
batch_size = 5  # for train & val. modify according to your GPU memory and data
img_height = img_width = 224  # picture size (imagenet challenge)
channel = 3  # RGB=3, grayscale=1
seed = random.randint(0, 100)  # use for shuffle=True (not recommend, shuffle will be bad for debugging)

# %%
def data_generater(path, img_width, img_height):
    data_gen_args = dict(rescale=1./255,
                         rotation_range=5,
                         shear_range=0.2,
                         zoom_range=0.2,
                         vertical_flip=True,
                         horizontal_flip=True)
    # train data generator
    train_datagen = keras.preprocessing.image.ImageDataGenerator(**data_gen_args)

    data = train_datagen.flow_from_directory(
            path,
            target_size=(img_width, img_height),
            batch_size=batch_size,
            class_mode='categorical',
            color_mode='rgb',
            shuffle=True)
    return data

# %%
train_generator = data_generater(train_path, img_width, img_height)
val_generator = data_generater(val_path, img_width, img_height)
# Out:
# Found 20 images belonging to 2 classes.
# Found 20 images belonging to 2 classes.

# %% [markdown]
# ------------------請依照你的想法修改模型------------------

# %%
model = layers.Input(shape=(224, 224, 3))
x = layers.Flatten()(model)                        # 將圖片攤平
x = layers.Dense(32, activation='relu')(x)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dense(2, activation='softmax')(x)                      # 注意:最後一層要為你的類別數 

network = keras.Model(inputs=model, outputs=x)

network.compile(optimizer='SGD',     # 可改成 'SGD' adam
               loss='categorical_crossentropy',
               metrics=['accuracy'])

# %% [markdown]
# --------------------------------cell2 end------------------------------------

# %%
STEP_SIZE_TRAIN = train_generator.n//train_generator.batch_size
STEP_SIZE_VALID = val_generator.n//val_generator.batch_size

history = network.fit_generator(generator=train_generator,
                                     steps_per_epoch=STEP_SIZE_TRAIN,
                                     validation_data=val_generator,
                                     validation_steps=STEP_SIZE_VALID,
                                     epochs=num_epoch,
                                     initial_epoch=0,
                                     verbose=1,  #显示方式
                                     workers=1)
# Out:
# Epoch 1/60
# 4/4 [==============================] - 1s 210ms/step - loss: 0.6969 - accuracy: 0.5000 - val_loss: 0.6859 - val_accuracy: 0.5000
# Epoch 2/60
# 4/4 [==============================] - 1s 214ms/step - loss: 0.6992 - accuracy: 0.5000 - val_loss: 0.6795 - val_accuracy: 0.4500
# Epoch 3/60
# 4/4 [==============================] - 1s 216ms/step - loss: 0.6927 - accuracy: 0.5000 - val_loss: 0.6886 - val_accuracy: 0.4500
# Epoch 4/60
# 4/4 [==============================] - 1s 228ms/step - loss: 0.6931 - accuracy: 0.5500 - val_loss: 0.7078 - val_accuracy: 0.4500
# Epoch 5/60
# 4/4 [==============================] - 1s 223ms/step - loss: 0.7077 - accuracy: 0.5000 - val_loss: 0.6974 - val_accuracy: 0.5000
# Epoch 6/60
# 4/4 [==============================] - 1s 214ms/step - loss: 0.7045 - accuracy: 0.3000 - val_loss: 0.6971 - val_accuracy: 0.5000
# Epoch 7/60
# 4/4 [==============================] - 1s 220ms/step - loss: 0.6966 - accuracy: 0.4500 - val_loss: 0.6925 - val_accuracy: 0.7500
# Epoch 8/60
# 4/4 [==============================] - 1s 221ms/step - loss: 0.6968 - accuracy: 0.6500 - val_loss: 0.6864 - val_accuracy: 0.4500
# Epoch 9/60
# 4/4 [==============================] - 1s 225ms/step - loss: 0.6930 - accuracy: 0.5500 - val_loss: 0.6896 - val_accuracy: 0.5000
# Epoch 10/60
# 4/4 [==============================] - 1s 219ms/step - loss: 0.7030 - accuracy: 0.4500 - val_loss: 0.6971 - val_accuracy: 0.5000
# Epoch 11/60
# 4/4 [==============================] - 1s 256ms/step - loss: 0.6950 - accuracy: 0.5000 - val_loss: 0.6672 - val_accuracy: 0.5000
# Epoch 12/60
# 4/4 [==============================] - 1s 230ms/step - loss: 0.7301 - accuracy: 0.5500 - val_loss: 0.6992 - val_accuracy: 0.5000
# Epoch 13/60
# 4/4 [==============================] - 1s 225ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6945 - val_accuracy: 0.5000
# Epoch 14/60
# 4/4 [==============================] - 1s 224ms/step - loss: 0.7034 - accuracy: 0.3500 - val_loss: 0.6901 - val_accuracy: 0.6000
# Epoch 15/60
# 4/4 [==============================] - 1s 216ms/step - loss: 0.6936 - accuracy: 0.5500 - val_loss: 0.6897 - val_accuracy: 0.6500
# Epoch 16/60
# 4/4 [==============================] - 1s 219ms/step - loss: 0.6949 - accuracy: 0.5000 - val_loss: 0.6952 - val_accuracy: 0.5000
# Epoch 17/60
# 4/4 [==============================] - 1s 214ms/step - loss: 0.7070 - accuracy: 0.4000 - val_loss: 0.6926 - val_accuracy: 0.4500
# Epoch 18/60
# 4/4 [==============================] - 1s 234ms/step - loss: 0.6919 - accuracy: 0.4500 - val_loss: 0.6999 - val_accuracy: 0.4500
# Epoch 19/60
# 4/4 [==============================] - 1s 224ms/step - loss: 0.6976 - accuracy: 0.5000 - val_loss: 0.6888 - val_accuracy: 0.4500
# Epoch 20/60
# 4/4 [==============================] - 1s 232ms/step - loss: 0.6904 - accuracy: 0.6500 - val_loss: 0.7089 - val_accuracy: 0.4500
# Epoch 21/60
# 4/4 [==============================] - 1s 227ms/step - loss: 0.6983 - accuracy: 0.5500 - val_loss: 0.6941 - val_accuracy: 0.5500
# Epoch 22/60
# 4/4 [==============================] - 1s 223ms/step - loss: 0.6941 - accuracy: 0.4500 - val_loss: 0.6917 - val_accuracy: 0.7500
# Epoch 23/60
# 4/4 [==============================] - 1s 227ms/step - loss: 0.6952 - accuracy: 0.4500 - val_loss: 0.6982 - val_accuracy: 0.4500
# Epoch 24/60
# 4/4 [==============================] - 1s 234ms/step - loss: 0.6979 - accuracy: 0.5000 - val_loss: 0.6925 - val_accuracy: 0.5500
# Epoch 25/60
# 4/4 [==============================] - 1s 222ms/step - loss: 0.6964 - accuracy: 0.5500 - val_loss: 0.6952 - val_accuracy: 0.5500
# Epoch 26/60
# 4/4 [==============================] - 1s 234ms/step - loss: 0.6903 - accuracy: 0.6000 - val_loss: 0.6904 - val_accuracy: 0.4500
# Epoch 27/60
# 4/4 [==============================] - 1s 227ms/step - loss: 0.6962 - accuracy: 0.4500 - val_loss: 0.6965 - val_accuracy: 0.5000
# Epoch 28/60
# 4/4 [==============================] - 1s 230ms/step - loss: 0.6889 - accuracy: 0.6500 - val_loss: 0.6743 - val_accuracy: 0.4500
# Epoch 29/60
# 4/4 [==============================] - 1s 238ms/step - loss: 0.7024 - accuracy: 0.5000 - val_loss: 0.6859 - val_accuracy: 0.6000
# Epoch 30/60
# 4/4 [==============================] - 1s 241ms/step - loss: 0.6939 - accuracy: 0.5000 - val_loss: 0.6897 - val_accuracy: 0.4500
# Epoch 31/60
# 4/4 [==============================] - 1s 230ms/step - loss: 0.6918 - accuracy: 0.4500 - val_loss: 0.6936 - val_accuracy: 0.6000
# Epoch 32/60
# 4/4 [==============================] - 1s 250ms/step - loss: 0.7032 - accuracy: 0.7500 - val_loss: 0.6927 - val_accuracy: 0.4500
# Epoch 33/60
# 4/4 [==============================] - 1s 245ms/step - loss: 0.6991 - accuracy: 0.5500 - val_loss: 0.6937 - val_accuracy: 0.4500
# Epoch 34/60
# 4/4 [==============================] - 1s 311ms/step - loss: 0.6896 - accuracy: 0.6000 - val_loss: 0.6926 - val_accuracy: 0.6000
# Epoch 35/60
# 4/4 [==============================] - 1s 248ms/step - loss: 0.6900 - accuracy: 0.5500 - val_loss: 0.7057 - val_accuracy: 0.4500
# Epoch 36/60
# 4/4 [==============================] - 1s 249ms/step - loss: 0.6922 - accuracy: 0.5000 - val_loss: 0.6963 - val_accuracy: 0.4500
# Epoch 37/60
# 4/4 [==============================] - 1s 245ms/step - loss: 0.6888 - accuracy: 0.5500 - val_loss: 0.7068 - val_accuracy: 0.5000
# Epoch 38/60
# 4/4 [==============================] - 1s 269ms/step - loss: 0.6853 - accuracy: 0.7000 - val_loss: 0.7149 - val_accuracy: 0.5000
# Epoch 39/60
# 4/4 [==============================] - 1s 247ms/step - loss: 0.6844 - accuracy: 0.6500 - val_loss: 0.6851 - val_accuracy: 0.4500
# Epoch 40/60
# 4/4 [==============================] - 1s 333ms/step - loss: 0.6975 - accuracy: 0.4500 - val_loss: 0.6927 - val_accuracy: 0.6000
# Epoch 41/60
# 4/4 [==============================] - 2s 415ms/step - loss: 0.6971 - accuracy: 0.5500 - val_loss: 0.6826 - val_accuracy: 0.5500
# Epoch 42/60
# 4/4 [==============================] - 1s 332ms/step - loss: 0.6956 - accuracy: 0.4500 - val_loss: 0.6918 - val_accuracy: 0.5000
# Epoch 43/60
# 4/4 [==============================] - 2s 380ms/step - loss: 0.7090 - accuracy: 0.5500 - val_loss: 0.7026 - val_accuracy: 0.5000
# Epoch 44/60
# 4/4 [==============================] - 2s 469ms/step - loss: 0.6957 - accuracy: 0.4500 - val_loss: 0.6874 - val_accuracy: 0.5500
# Epoch 45/60
# 4/4 [==============================] - 2s 457ms/step - loss: 0.7065 - accuracy: 0.5500 - val_loss: 0.7034 - val_accuracy: 0.5000
# Epoch 46/60
# 4/4 [==============================] - 1s 322ms/step - loss: 0.6898 - accuracy: 0.5500 - val_loss: 0.6988 - val_accuracy: 0.5500
# Epoch 47/60
# 4/4 [==============================] - 1s 315ms/step - loss: 0.6876 - accuracy: 0.5500 - val_loss: 0.7021 - val_accuracy: 0.5000
# Epoch 48/60
# 4/4 [==============================] - 1s 287ms/step - loss: 0.6762 - accuracy: 0.6000 - val_loss: 0.6873 - val_accuracy: 0.4500
# Epoch 49/60
# 4/4 [==============================] - 1s 284ms/step - loss: 0.6765 - accuracy: 0.6500 - val_loss: 0.7087 - val_accuracy: 0.6000
# Epoch 50/60
# 4/4 [==============================] - 1s 302ms/step - loss: 0.6778 - accuracy: 0.6000 - val_loss: 0.6683 - val_accuracy: 0.4500
# Epoch 51/60
# 4/4 [==============================] - 1s 320ms/step - loss: 0.6864 - accuracy: 0.6500 - val_loss: 0.7097 - val_accuracy: 0.5500
# Epoch 52/60
# 4/4 [==============================] - 1s 327ms/step - loss: 0.6966 - accuracy: 0.5500 - val_loss: 0.6630 - val_accuracy: 0.4500
# Epoch 53/60
# 4/4 [==============================] - 1s 355ms/step - loss: 0.6762 - accuracy: 0.7000 - val_loss: 0.6690 - val_accuracy: 0.4500
# Epoch 54/60
# 4/4 [==============================] - 1s 307ms/step - loss: 0.6712 - accuracy: 0.6500 - val_loss: 0.6438 - val_accuracy: 0.4500
# Epoch 55/60
# 4/4 [==============================] - 1s 312ms/step - loss: 0.6888 - accuracy: 0.6500 - val_loss: 0.6891 - val_accuracy: 0.4000
# Epoch 56/60
# 4/4 [==============================] - 1s 340ms/step - loss: 0.6933 - accuracy: 0.7000 - val_loss: 0.6886 - val_accuracy: 0.5500
# Epoch 57/60
# 4/4 [==============================] - 1s 346ms/step - loss: 0.6835 - accuracy: 0.6000 - val_loss: 0.6842 - val_accuracy: 0.4500
# Epoch 58/60
# 4/4 [==============================] - 2s 412ms/step - loss: 0.6775 - accuracy: 0.6500 - val_loss: 0.6821 - val_accuracy: 0.4500
# Epoch 59/60
# 4/4 [==============================] - 2s 559ms/step - loss: 0.6990 - accuracy: 0.5000 - val_loss: 0.6885 - val_accuracy: 0.5500
# Epoch 60/60
# 4/4 [==============================] - 2s 447ms/step - loss: 0.7113 - accuracy: 0.4500 - val_loss: 0.6765 - val_accuracy: 0.5000

# %%
# plot model loss & save
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig('VGG16_custom_model_loss_summary_graph.png')
plt.show()


# plot model accuracy & save
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig('VGG16_custom_model_accuracy_summary_graph.png')
plt.show()

# %%
def preprocess_image(path=test_image_path):
    img = Image.open(path)
    img = img.resize((img_height, img_width), Image.BICUBIC)
    if img.mode != 'RGB':
        img = img.convert('RGB')
    x = np.asarray(img)   # object to ndarray
    x = x / 255.
    batch_x = np.asarray([x])   # create for a batch [1, img_width, img_height, channel]
    return batch_x


img = preprocess_image(test_image_path)
mth2_predicted = network.predict(img)
mth2_index = np.argmax(mth2_predicted[0], axis=0)
mth2_predicted_answer = list(train_generator.class_indices.keys())[mth2_index]   # get the class name you predicted



img_bgr = cv2.imread(test_image_path)
img_rgb = img_bgr[:,:,:]
#print(img_bgr)
plt.imshow(img_bgr)
plt.show()


print('Predict this image as \"{}\"\n'.format(mth2_predicted_answer))
for label in range(len(train_generator.class_indices)):
    print('The probability that this is a {} is: {:.8f}\n'.format(list(train_generator.class_indices.keys())[label],
                                                                  mth2_predicted[0][label]))
# Out:
# Predict this image as "nike"
#
# The probability that this is a adidas is: 0.47839642
#
# The probability that this is a nike is: 0.52160358
